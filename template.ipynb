# %% [markdown]
# ## Problem #xyz: Title
# [Link to Problem](https://projecteuler.net/problem=xyz)
#
# ### Problem Description
#
# Description

# %% [markdown]
# ### Approach
#
# - idea 1
# - idea 2

# %%
if __name__ == "__main__":
    print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ###### Result: x | Execution time: s

# %% [markdown]
# ### Complexity analysis

# %% [markdown]
# ##### Tags: #factorials
